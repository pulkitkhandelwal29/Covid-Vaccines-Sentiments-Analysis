# %% [markdown]
# # Public Sentiment Analysis (Zonal Wise)
#
# In this notebook, we will be doing Sentiment Analysis on **Covishield** and **Covaxin** cleaned Tweets collected from different zones of India :-
#
# * North Zone
# * East Zone
# * West Zone
# * South Zone
# * North-East Zone

# %%
#Importing libraries 

#Data Manipulation Library
import pandas as pd

#Natural Language Processing Library
import nltk

# %% [markdown]
# ## Covishield (Zonal Wise)

# %% [markdown]
# ### North Wise

# %%
#Reading CSV file
covishield_north = pd.read_csv('covishield_north_clean_tweets.csv')

# %%
#Head of dataframe
covishield_north.head()
# Out:
#       user_location  tweet_created_at  \
# 0  Ghaziabad, India  18-04-2021 13:07
# 1         New Delhi  18-04-2021 13:07
# 2  New Delhi, India  18-04-2021 12:53
# 3         New Delhi  18-04-2021 12:39
# 4    Lucknow, India  18-04-2021 12:37
#
#                                           tweet_text  \
# 0  @sandesh_ic @iAsura_ &amp; In my family 2 docs...
# 1  #AndhraPradesh on Sunday received two lakh dos...
# 2  @ShekharGupta 1/2\nYes, more brand vaccine pro...
# 3  @cloudnikki @ArvinderSoin @freedoomer 2nd dose...
# 4  @DrKKAggarwal My father has tested positive af...
#
#                                          tweet_clean
# 0     amp  In my family 2 docs have got Covaxin  ...
# 1   AndhraPradesh on Sunday received two lakh dos...
# 2   1 2 Yes more brand vaccine production is very...
# 3     2nd dose he got a month ago so 1st dose ano...
# 4   My father has tested positive after 1st dose ...

# %% [markdown]
# ### Sentiment Analysis

# %%
# Sentiment Analysis (VADER)

from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# **VADER ( Valence Aware Dictionary for Sentiment Reasoning)** is a model used for text sentiment analysis that is sensitive to both polarity (positive/negative) and intensity (strength) of emotion. It is available in the NLTK package and can be applied directly to unlabeled text data.

# %%
# Creating Object of Sentiment Intensity Analyser

sid = SentimentIntensityAnalyzer()

# %%
#Finding Polarity scores on tweet

sid.polarity_scores(covishield_north['tweet_clean'][1])
#The compound scores of 0-1 is positive, 0 is for neutral, -0 to -1 for negative.
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
#Creating Scores column to record polarity scores of tweet_clean column by lambda function.

covishield_north['scores']=covishield_north['tweet_clean'].apply(lambda tweet_clean:sid.polarity_scores(tweet_clean))

# %% [markdown]
# **Polarity Score** provides Positive, Negative, Neutral and Compound score of the sentences provided to it

# %%
#Head of Dataframe after scores column
covishield_north.head()
# Out:
#       user_location  tweet_created_at  \
# 0  Ghaziabad, India  18-04-2021 13:07
# 1         New Delhi  18-04-2021 13:07
# 2  New Delhi, India  18-04-2021 12:53
# 3         New Delhi  18-04-2021 12:39
# 4    Lucknow, India  18-04-2021 12:37
#
#                                           tweet_text  \
# 0  @sandesh_ic @iAsura_ &amp; In my family 2 docs...
# 1  #AndhraPradesh on Sunday received two lakh dos...
# 2  @ShekharGupta 1/2\nYes, more brand vaccine pro...
# 3  @cloudnikki @ArvinderSoin @freedoomer 2nd dose...
# 4  @DrKKAggarwal My father has tested positive af...
#
#                                          tweet_clean  \
# 0     amp  In my family 2 docs have got Covaxin  ...
# 1   AndhraPradesh on Sunday received two lakh dos...
# 2   1 2 Yes more brand vaccine production is very...
# 3     2nd dose he got a month ago so 1st dose ano...
# 4   My father has tested positive after 1st dose ...
#
#                                               scores
# 0  {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'comp...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'comp...
# 3  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'comp...
# 4  {'neg': 0.191, 'neu': 0.764, 'pos': 0.045, 'co...

# %%
#Creating Compound column by retrieving compound from dictionary of scores.

covishield_north['compound']=covishield_north['scores'].apply(lambda d:d['compound'])

# %%
#Head of Dataframe after getting Compount Score
covishield_north.head()
# Out:
#       user_location  tweet_created_at  \
# 0  Ghaziabad, India  18-04-2021 13:07
# 1         New Delhi  18-04-2021 13:07
# 2  New Delhi, India  18-04-2021 12:53
# 3         New Delhi  18-04-2021 12:39
# 4    Lucknow, India  18-04-2021 12:37
#
#                                           tweet_text  \
# 0  @sandesh_ic @iAsura_ &amp; In my family 2 docs...
# 1  #AndhraPradesh on Sunday received two lakh dos...
# 2  @ShekharGupta 1/2\nYes, more brand vaccine pro...
# 3  @cloudnikki @ArvinderSoin @freedoomer 2nd dose...
# 4  @DrKKAggarwal My father has tested positive af...
#
#                                          tweet_clean  \
# 0     amp  In my family 2 docs have got Covaxin  ...
# 1   AndhraPradesh on Sunday received two lakh dos...
# 2   1 2 Yes more brand vaccine production is very...
# 3     2nd dose he got a month ago so 1st dose ano...
# 4   My father has tested positive after 1st dose ...
#
#                                               scores  compound
# 0  {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'comp...    0.3875
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 2  {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'comp...    0.6124
# 3  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'comp...    0.4019
# 4  {'neg': 0.191, 'neu': 0.764, 'pos': 0.045, 'co...   -0.8151

# %%
#Creating Sentiments Subdivision Category from the Compound score

covishield_north['sentiment'] = 'Nan'
for i in range(len(covishield_north)):
    # Weak Positive Category
    if(covishield_north['compound'][i] > 0 and covishield_north['compound'][i] < 0.8):
        covishield_north['sentiment'][i] = 'Weak Positive'
    # Strong Positive Category  
    elif(covishield_north['compound'][i]) >= 0.8 and covishield_north['compound'][i] <= 1:
        covishield_north['sentiment'][i] = 'Strong Positive'
    # Weak Negative Category
    elif(covishield_north['compound'][i] < 0 and covishield_north['compound'][i] > -0.8):
        covishield_north['sentiment'][i] = 'Weak Negative'
    # Strong Negative Category
    elif(covishield_north['compound'][i]) <= -0.8 and covishield_north['compound'][i] >= -1:
        covishield_north['sentiment'][i] = 'Strong Negative'
    # Neutral Category
    else:
        covishield_north['sentiment'][i] = 'Neutral'
# Out:
# <ipython-input-116-dc30d2c4ef59>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_north['sentiment'][i] = 'Weak Positive'
# <ipython-input-116-dc30d2c4ef59>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_north['sentiment'][i] = 'Neutral'
# <ipython-input-116-dc30d2c4ef59>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_north['sentiment'][i] = 'Strong Negative'
# <ipython-input-116-dc30d2c4ef59>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_north['sentiment'][i] = 'Weak Negative'
# <ipython-input-116-dc30d2c4ef59>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_north['sentiment'][i] = 'Strong Positive'

# %%
#Head of dataframe after 'sentiment' column
covishield_north.head()
# Out:
#       user_location  tweet_created_at  \
# 0  Ghaziabad, India  18-04-2021 13:07
# 1         New Delhi  18-04-2021 13:07
# 2  New Delhi, India  18-04-2021 12:53
# 3         New Delhi  18-04-2021 12:39
# 4    Lucknow, India  18-04-2021 12:37
#
#                                           tweet_text  \
# 0  @sandesh_ic @iAsura_ &amp; In my family 2 docs...
# 1  #AndhraPradesh on Sunday received two lakh dos...
# 2  @ShekharGupta 1/2\nYes, more brand vaccine pro...
# 3  @cloudnikki @ArvinderSoin @freedoomer 2nd dose...
# 4  @DrKKAggarwal My father has tested positive af...
#
#                                          tweet_clean  \
# 0     amp  In my family 2 docs have got Covaxin  ...
# 1   AndhraPradesh on Sunday received two lakh dos...
# 2   1 2 Yes more brand vaccine production is very...
# 3     2nd dose he got a month ago so 1st dose ano...
# 4   My father has tested positive after 1st dose ...
#
#                                               scores  compound  \
# 0  {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'comp...    0.3875
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 2  {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'comp...    0.6124
# 3  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'comp...    0.4019
# 4  {'neg': 0.191, 'neu': 0.764, 'pos': 0.045, 'co...   -0.8151
#
#          sentiment
# 0    Weak Positive
# 1          Neutral
# 2    Weak Positive
# 3    Weak Positive
# 4  Strong Negative

# %%
# Different sentiments category 
covishield_north['sentiment'].value_counts()
# Out:
# Weak Positive      240
# Neutral            175
# Weak Negative      130
# Strong Positive     29
# Strong Negative     20
# Name: sentiment, dtype: int64

# %%
# Percentage of Above Different Sentiments Category for Visualisation

for i in range(len(covishield_north['sentiment'].value_counts())):
    percentage = covishield_north['sentiment'].value_counts()[i] / len(covishield_north)
    print(covishield_north['sentiment'].value_counts().index[i], round(percentage*100,2),"%", "rounded to",round(percentage*100),"%")
# Out:
# Weak Positive 40.4 % rounded to 40 %
# Neutral 29.46 % rounded to 29 %
# Weak Negative 21.89 % rounded to 22 %
# Strong Positive 4.88 % rounded to 5 %
# Strong Negative 3.37 % rounded to 3 %

# %% [markdown]
# ### East Wise

# %%
#Reading CSV file
covishield_east = pd.read_csv('covishield_east_clean_tweets.csv')

# %%
#Head of dataframe
covishield_east.head()
# Out:
#      user_location  tweet_created_at  \
# 0   Lucknow, India  18-04-2021 12:37
# 1  Varanasi, India  18-04-2021 12:07
# 2           Patna   18-04-2021 11:43
# 3          Lucknow  18-04-2021 11:08
# 4   Dhanbad, India  18-04-2021 08:41
#
#                                           tweet_text  \
# 0  @DrKKAggarwal My father has tested positive af...
# 1  @ArvinderSoin Sir, how do you see the response...
# 2           @deerao Planning to take Covishield jab.
# 3  @aarohi_vns Data of what vaccine 1st dose was ...
# 4                    Dad got vaccinated\n#Covishield
#
#                                          tweet_clean
# 0   My father has tested positive after 1st dose ...
# 1   Sir how do you see the response after 1st dos...
# 2                   Planning to take Covishield jab
# 3   Data of what vaccine 1st dose was taken  cova...
# 4                     Dad got vaccinated  Covishield

# %% [markdown]
# ### Sentiment Analysis

# %%
#Finding Polarity scores on tweet

sid.polarity_scores(covishield_east['tweet_clean'][1])
#The compound scores of 0-1 is positive, 0 is for neutral, -0 to -1 for negative.
# Out:
# {'neg': 0.143, 'neu': 0.736, 'pos': 0.12, 'compound': 0.1027}

# %%
#Creating Scores column to record polarity scores of tweet_clean column by lambda function.

covishield_east['scores']=covishield_east['tweet_clean'].apply(lambda tweet_clean:sid.polarity_scores(tweet_clean))

# %%
#Head of Dataframe after scores column
covishield_east.head()
# Out:
#      user_location  tweet_created_at  \
# 0   Lucknow, India  18-04-2021 12:37
# 1  Varanasi, India  18-04-2021 12:07
# 2           Patna   18-04-2021 11:43
# 3          Lucknow  18-04-2021 11:08
# 4   Dhanbad, India  18-04-2021 08:41
#
#                                           tweet_text  \
# 0  @DrKKAggarwal My father has tested positive af...
# 1  @ArvinderSoin Sir, how do you see the response...
# 2           @deerao Planning to take Covishield jab.
# 3  @aarohi_vns Data of what vaccine 1st dose was ...
# 4                    Dad got vaccinated\n#Covishield
#
#                                          tweet_clean  \
# 0   My father has tested positive after 1st dose ...
# 1   Sir how do you see the response after 1st dos...
# 2                   Planning to take Covishield jab
# 3   Data of what vaccine 1st dose was taken  cova...
# 4                     Dad got vaccinated  Covishield
#
#                                               scores
# 0  {'neg': 0.191, 'neu': 0.764, 'pos': 0.045, 'co...
# 1  {'neg': 0.143, 'neu': 0.736, 'pos': 0.12, 'com...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...

# %%
#Creating Compound column by retrieving compound from dictionary of scores.

covishield_east['compound']=covishield_east['scores'].apply(lambda d:d['compound'])

# %%
#Head of Dataframe after getting Compound Score
covishield_east.head()
# Out:
#      user_location  tweet_created_at  \
# 0   Lucknow, India  18-04-2021 12:37
# 1  Varanasi, India  18-04-2021 12:07
# 2           Patna   18-04-2021 11:43
# 3          Lucknow  18-04-2021 11:08
# 4   Dhanbad, India  18-04-2021 08:41
#
#                                           tweet_text  \
# 0  @DrKKAggarwal My father has tested positive af...
# 1  @ArvinderSoin Sir, how do you see the response...
# 2           @deerao Planning to take Covishield jab.
# 3  @aarohi_vns Data of what vaccine 1st dose was ...
# 4                    Dad got vaccinated\n#Covishield
#
#                                          tweet_clean  \
# 0   My father has tested positive after 1st dose ...
# 1   Sir how do you see the response after 1st dos...
# 2                   Planning to take Covishield jab
# 3   Data of what vaccine 1st dose was taken  cova...
# 4                     Dad got vaccinated  Covishield
#
#                                               scores  compound
# 0  {'neg': 0.191, 'neu': 0.764, 'pos': 0.045, 'co...   -0.8151
# 1  {'neg': 0.143, 'neu': 0.736, 'pos': 0.12, 'com...    0.1027
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000

# %%
#Creating Sentiments Subdivision Category from the Compound score

covishield_east['sentiment'] = 'Nan'
for i in range(len(covishield_east)):
    # Weak Positive Category
    if(covishield_east['compound'][i] > 0 and covishield_east['compound'][i] < 0.8):
        covishield_east['sentiment'][i] = 'Weak Positive'
    # Strong Positive Category 
    elif(covishield_east['compound'][i]) >= 0.8 and covishield_east['compound'][i] <= 1:
        covishield_east['sentiment'][i] = 'Strong Positive'
    # Weak Negative Category
    elif(covishield_east['compound'][i] < 0 and covishield_east['compound'][i] > -0.8):
        covishield_east['sentiment'][i] = 'Weak Negative'
    # Strong Negative Category
    elif(covishield_east['compound'][i]) <= -0.8 and covishield_east['compound'][i] >= -1:
        covishield_east['sentiment'][i] = 'Strong Negative'
    # Neutral Category
    else:
        covishield_east['sentiment'][i] = 'Neutral'
# Out:
# <ipython-input-128-0f7fb03350a9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_east['sentiment'][i] = 'Strong Negative'
# <ipython-input-128-0f7fb03350a9>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_east['sentiment'][i] = 'Weak Positive'
# <ipython-input-128-0f7fb03350a9>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_east['sentiment'][i] = 'Neutral'
# <ipython-input-128-0f7fb03350a9>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_east['sentiment'][i] = 'Weak Negative'
# <ipython-input-128-0f7fb03350a9>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_east['sentiment'][i] = 'Strong Positive'

# %%
#Head of dataframe after 'sentiment' column
covishield_east.head()
# Out:
#      user_location  tweet_created_at  \
# 0   Lucknow, India  18-04-2021 12:37
# 1  Varanasi, India  18-04-2021 12:07
# 2           Patna   18-04-2021 11:43
# 3          Lucknow  18-04-2021 11:08
# 4   Dhanbad, India  18-04-2021 08:41
#
#                                           tweet_text  \
# 0  @DrKKAggarwal My father has tested positive af...
# 1  @ArvinderSoin Sir, how do you see the response...
# 2           @deerao Planning to take Covishield jab.
# 3  @aarohi_vns Data of what vaccine 1st dose was ...
# 4                    Dad got vaccinated\n#Covishield
#
#                                          tweet_clean  \
# 0   My father has tested positive after 1st dose ...
# 1   Sir how do you see the response after 1st dos...
# 2                   Planning to take Covishield jab
# 3   Data of what vaccine 1st dose was taken  cova...
# 4                     Dad got vaccinated  Covishield
#
#                                               scores  compound  \
# 0  {'neg': 0.191, 'neu': 0.764, 'pos': 0.045, 'co...   -0.8151
# 1  {'neg': 0.143, 'neu': 0.736, 'pos': 0.12, 'com...    0.1027
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
#
#          sentiment
# 0  Strong Negative
# 1    Weak Positive
# 2          Neutral
# 3          Neutral
# 4          Neutral

# %%
# Different sentiments category 
covishield_east['sentiment'].value_counts()
# Out:
# Neutral            49
# Weak Positive      33
# Weak Negative      27
# Strong Positive     5
# Strong Negative     3
# Name: sentiment, dtype: int64

# %%
# Percentage of Above Different Sentiments Category for Visualisation

for i in range(len(covishield_east['sentiment'].value_counts())):
    percentage = covishield_east['sentiment'].value_counts()[i] / len(covishield_east)
    print(covishield_east['sentiment'].value_counts().index[i], round(percentage*100,2),"%", "rounded to",round(percentage*100),"%")
# Out:
# Neutral 41.88 % rounded to 42 %
# Weak Positive 28.21 % rounded to 28 %
# Weak Negative 23.08 % rounded to 23 %
# Strong Positive 4.27 % rounded to 4 %
# Strong Negative 2.56 % rounded to 3 %

# %% [markdown]
# ### West Wise

# %%
#Reading CSV file
covishield_west = pd.read_csv('covishield_west_clean_tweets.csv')

# %%
#Head of dataframe
covishield_west.head()
# Out:
#            user_location  tweet_created_at  \
# 0                 India   18-04-2021 12:55
# 1                 Bharat  18-04-2021 12:54
# 2                  India  18-04-2021 12:52
# 3  Madhya Pradesh, India  18-04-2021 12:52
# 4         Gurgaon & Kota  18-04-2021 12:49
#
#                                           tweet_text  \
# 0  By the grace of Mahadev &amp; Maa Parvati, App...
# 1  https://t.co/GGvYPeVUPS\nShameful.. #IndiaFigh...
# 2  Goa received 1,50,000 doses of Covishield vacc...
# 3  @prik1408 @DipshikhaGhosh Can't Comment On The...
# 4  @NakuulMehta @ajaxsingh - 15,378 Covid "treatm...
#
#                                          tweet_clean
# 0  By the grace of Mahadev  amp  Maa Parvati Appa...
# 1                      Shameful    IndiaFightsCorona
# 2  Goa received 150000 doses of Covishield vaccin...
# 3    Can t Comment On The Efficacy Or Comparison ...
# 4      15378 Covid  treatment  facilities created...

# %% [markdown]
# ### Sentiment Analysis

# %%
#Finding Polarity scores on tweet

sid.polarity_scores(covishield_west['tweet_clean'][1])
#The compound scores of 0-1 is positive, 0 is for neutral, -0 to -1 for negative.
# Out:
# {'neg': 0.762, 'neu': 0.238, 'pos': 0.0, 'compound': -0.4939}

# %%
#Creating Scores column to record polarity scores of tweet_clean column by lambda function.

covishield_west['scores']=covishield_west['tweet_clean'].apply(lambda tweet_clean:sid.polarity_scores(tweet_clean))

# %%
#Head of Dataframe after scores column
covishield_west.head()
# Out:
#            user_location  tweet_created_at  \
# 0                 India   18-04-2021 12:55
# 1                 Bharat  18-04-2021 12:54
# 2                  India  18-04-2021 12:52
# 3  Madhya Pradesh, India  18-04-2021 12:52
# 4         Gurgaon & Kota  18-04-2021 12:49
#
#                                           tweet_text  \
# 0  By the grace of Mahadev &amp; Maa Parvati, App...
# 1  https://t.co/GGvYPeVUPS\nShameful.. #IndiaFigh...
# 2  Goa received 1,50,000 doses of Covishield vacc...
# 3  @prik1408 @DipshikhaGhosh Can't Comment On The...
# 4  @NakuulMehta @ajaxsingh - 15,378 Covid "treatm...
#
#                                          tweet_clean  \
# 0  By the grace of Mahadev  amp  Maa Parvati Appa...
# 1                      Shameful    IndiaFightsCorona
# 2  Goa received 150000 doses of Covishield vaccin...
# 3    Can t Comment On The Efficacy Or Comparison ...
# 4      15378 Covid  treatment  facilities created...
#
#                                               scores
# 0  {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'comp...
# 1  {'neg': 0.762, 'neu': 0.238, 'pos': 0.0, 'comp...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'comp...
# 4  {'neg': 0.056, 'neu': 0.779, 'pos': 0.165, 'co...

# %%
#Creating Compound column by retrieving compound from dictionary of scores.

covishield_west['compound']=covishield_west['scores'].apply(lambda d:d['compound'])

# %%
#Head of Dataframe after getting Compount Score
covishield_west.head()
# Out:
#            user_location  tweet_created_at  \
# 0                 India   18-04-2021 12:55
# 1                 Bharat  18-04-2021 12:54
# 2                  India  18-04-2021 12:52
# 3  Madhya Pradesh, India  18-04-2021 12:52
# 4         Gurgaon & Kota  18-04-2021 12:49
#
#                                           tweet_text  \
# 0  By the grace of Mahadev &amp; Maa Parvati, App...
# 1  https://t.co/GGvYPeVUPS\nShameful.. #IndiaFigh...
# 2  Goa received 1,50,000 doses of Covishield vacc...
# 3  @prik1408 @DipshikhaGhosh Can't Comment On The...
# 4  @NakuulMehta @ajaxsingh - 15,378 Covid "treatm...
#
#                                          tweet_clean  \
# 0  By the grace of Mahadev  amp  Maa Parvati Appa...
# 1                      Shameful    IndiaFightsCorona
# 2  Goa received 150000 doses of Covishield vaccin...
# 3    Can t Comment On The Efficacy Or Comparison ...
# 4      15378 Covid  treatment  facilities created...
#
#                                               scores  compound
# 0  {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'comp...    0.4215
# 1  {'neg': 0.762, 'neu': 0.238, 'pos': 0.0, 'comp...   -0.4939
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 3  {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'comp...    0.5106
# 4  {'neg': 0.056, 'neu': 0.779, 'pos': 0.165, 'co...    0.6124

# %%
#Creating Sentiments Subdivision Category from the Compound score

covishield_west['sentiment'] = 'Nan'
for i in range(len(covishield_west)):
    # Weak Positive Category
    if(covishield_west['compound'][i] > 0 and covishield_west['compound'][i] < 0.8):
        covishield_west['sentiment'][i] = 'Weak Positive'
    # Strong Positive Category
    elif(covishield_west['compound'][i]) >= 0.8 and covishield_west['compound'][i] <= 1:
        covishield_west['sentiment'][i] = 'Strong Positive'
    # Weak Negative Category
    elif(covishield_west['compound'][i] < 0 and covishield_west['compound'][i] > -0.8):
        covishield_west['sentiment'][i] = 'Weak Negative'
    # Strong Negative Category
    elif(covishield_west['compound'][i]) <= -0.8 and covishield_west['compound'][i] >= -1:
        covishield_west['sentiment'][i] = 'Strong Negative'
    # Neutral Category
    else:
        covishield_west['sentiment'][i] = 'Neutral'
# Out:
# <ipython-input-138-90f3bf89d9df>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_west['sentiment'][i] = 'Weak Positive'
# <ipython-input-138-90f3bf89d9df>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_west['sentiment'][i] = 'Weak Negative'
# <ipython-input-138-90f3bf89d9df>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_west['sentiment'][i] = 'Neutral'
# <ipython-input-138-90f3bf89d9df>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_west['sentiment'][i] = 'Strong Positive'
# <ipython-input-138-90f3bf89d9df>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_west['sentiment'][i] = 'Strong Negative'

# %%
#Head of dataframe after 'sentiment' column
covishield_west.head()
# Out:
#            user_location  tweet_created_at  \
# 0                 India   18-04-2021 12:55
# 1                 Bharat  18-04-2021 12:54
# 2                  India  18-04-2021 12:52
# 3  Madhya Pradesh, India  18-04-2021 12:52
# 4         Gurgaon & Kota  18-04-2021 12:49
#
#                                           tweet_text  \
# 0  By the grace of Mahadev &amp; Maa Parvati, App...
# 1  https://t.co/GGvYPeVUPS\nShameful.. #IndiaFigh...
# 2  Goa received 1,50,000 doses of Covishield vacc...
# 3  @prik1408 @DipshikhaGhosh Can't Comment On The...
# 4  @NakuulMehta @ajaxsingh - 15,378 Covid "treatm...
#
#                                          tweet_clean  \
# 0  By the grace of Mahadev  amp  Maa Parvati Appa...
# 1                      Shameful    IndiaFightsCorona
# 2  Goa received 150000 doses of Covishield vaccin...
# 3    Can t Comment On The Efficacy Or Comparison ...
# 4      15378 Covid  treatment  facilities created...
#
#                                               scores  compound      sentiment
# 0  {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'comp...    0.4215  Weak Positive
# 1  {'neg': 0.762, 'neu': 0.238, 'pos': 0.0, 'comp...   -0.4939  Weak Negative
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        Neutral
# 3  {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'comp...    0.5106  Weak Positive
# 4  {'neg': 0.056, 'neu': 0.779, 'pos': 0.165, 'co...    0.6124  Weak Positive

# %%
# Different sentiments category
covishield_west['sentiment'].value_counts()
# Out:
# Weak Positive      349
# Neutral            299
# Weak Negative      213
# Strong Positive     19
# Strong Negative     13
# Name: sentiment, dtype: int64

# %%
# Percentage of Above Different Sentiments Category for Visualisation

for i in range(len(covishield_west['sentiment'].value_counts())):
    percentage = covishield_west['sentiment'].value_counts()[i] / len(covishield_west)
    print(covishield_west['sentiment'].value_counts().index[i], round(percentage*100,2),"%", "rounded to",round(percentage*100),"%")
# Out:
# Weak Positive 39.08 % rounded to 39 %
# Neutral 33.48 % rounded to 33 %
# Weak Negative 23.85 % rounded to 24 %
# Strong Positive 2.13 % rounded to 2 %
# Strong Negative 1.46 % rounded to 1 %

# %% [markdown]
# ### South Wise

# %%
#Reading CSV file
covishield_south = pd.read_csv('covishield_south_clean_tweets.csv')

# %%
#Head of dataframe
covishield_south.head()
# Out:
#       user_location     tweet_created_at  \
# 0         bangalore  2021-04-18 12:49:53
# 1  Bengaluru, India  2021-04-18 12:41:06
# 2           chennai  2021-04-18 12:14:46
# 3         Bangalore  2021-04-18 12:01:31
# 4           chennai  2021-04-18 11:58:46
#
#                                           tweet_text  \
# 0  @amitkr12jan @iAsura_ Health Workers who were ...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2  @Arunaurs @DrJoyeeta @OmairTAhmad @devangshuda...
# 3  @cspramesh Dr Pramesh, thank you for your thre...
# 4  @SerumInstIndia @PMOIndia \nreminder call from...
#
#                                          tweet_clean
# 0    Health Workers who were already vaccinated i...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2            But GoI yet to respond to    s reque...
# 3   Dr Pramesh thank you for your thread  But I n...
# 4     reminder call from hospital for 2nd dose co...

# %% [markdown]
# ### Sentiment Analysis

# %%
#Finding Polarity scores on tweet

sid.polarity_scores(covishield_south['tweet_clean'][1])
#The compound scores of 0-1 is positive, 0 is for neutral, -0 to -1 for negative.
# Out:
# {'neg': 0.042, 'neu': 0.897, 'pos': 0.061, 'compound': 0.25}

# %%
#Creating Scores column to record polarity scores of tweet_clean column by lambda function.

covishield_south['scores']=covishield_south['tweet_clean'].apply(lambda tweet_clean:sid.polarity_scores(tweet_clean))

# %%
#Head of Dataframe after scores column
covishield_south.head()
# Out:
#       user_location     tweet_created_at  \
# 0         bangalore  2021-04-18 12:49:53
# 1  Bengaluru, India  2021-04-18 12:41:06
# 2           chennai  2021-04-18 12:14:46
# 3         Bangalore  2021-04-18 12:01:31
# 4           chennai  2021-04-18 11:58:46
#
#                                           tweet_text  \
# 0  @amitkr12jan @iAsura_ Health Workers who were ...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2  @Arunaurs @DrJoyeeta @OmairTAhmad @devangshuda...
# 3  @cspramesh Dr Pramesh, thank you for your thre...
# 4  @SerumInstIndia @PMOIndia \nreminder call from...
#
#                                          tweet_clean  \
# 0    Health Workers who were already vaccinated i...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2            But GoI yet to respond to    s reque...
# 3   Dr Pramesh thank you for your thread  But I n...
# 4     reminder call from hospital for 2nd dose co...
#
#                                               scores
# 0  {'neg': 0.171, 'neu': 0.743, 'pos': 0.086, 'co...
# 1  {'neg': 0.042, 'neu': 0.897, 'pos': 0.061, 'co...
# 2  {'neg': 0.0, 'neu': 0.921, 'pos': 0.079, 'comp...
# 3  {'neg': 0.06, 'neu': 0.797, 'pos': 0.143, 'com...
# 4  {'neg': 0.24, 'neu': 0.76, 'pos': 0.0, 'compou...

# %%
#Creating Compound column by retrieving compound from dictionary of scores.

covishield_south['compound']=covishield_south['scores'].apply(lambda d:d['compound'])

# %%
#Head of Dataframe after getting Compount Score
covishield_south.head()
# Out:
#       user_location     tweet_created_at  \
# 0         bangalore  2021-04-18 12:49:53
# 1  Bengaluru, India  2021-04-18 12:41:06
# 2           chennai  2021-04-18 12:14:46
# 3         Bangalore  2021-04-18 12:01:31
# 4           chennai  2021-04-18 11:58:46
#
#                                           tweet_text  \
# 0  @amitkr12jan @iAsura_ Health Workers who were ...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2  @Arunaurs @DrJoyeeta @OmairTAhmad @devangshuda...
# 3  @cspramesh Dr Pramesh, thank you for your thre...
# 4  @SerumInstIndia @PMOIndia \nreminder call from...
#
#                                          tweet_clean  \
# 0    Health Workers who were already vaccinated i...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2            But GoI yet to respond to    s reque...
# 3   Dr Pramesh thank you for your thread  But I n...
# 4     reminder call from hospital for 2nd dose co...
#
#                                               scores  compound
# 0  {'neg': 0.171, 'neu': 0.743, 'pos': 0.086, 'co...   -0.6648
# 1  {'neg': 0.042, 'neu': 0.897, 'pos': 0.061, 'co...    0.2500
# 2  {'neg': 0.0, 'neu': 0.921, 'pos': 0.079, 'comp...    0.3612
# 3  {'neg': 0.06, 'neu': 0.797, 'pos': 0.143, 'com...    0.4588
# 4  {'neg': 0.24, 'neu': 0.76, 'pos': 0.0, 'compou...   -0.8678

# %%
#Creating Sentiments Subdivision Category from the Compound score

covishield_south['sentiment'] = 'Nan'
for i in range(len(covishield_south)):
    # Weak Positive Category
    if(covishield_south['compound'][i] > 0 and covishield_south['compound'][i] < 0.8):
        covishield_south['sentiment'][i] = 'Weak Positive'
    # Strong Positive Category 
    elif(covishield_south['compound'][i]) >= 0.8 and covishield_south['compound'][i] <= 1:
        covishield_south['sentiment'][i] = 'Strong Positive'
    # Weak Negative Category
    elif(covishield_south['compound'][i] < 0 and covishield_south['compound'][i] > -0.8):
        covishield_south['sentiment'][i] = 'Weak Negative'
    # Strong Negative Category
    elif(covishield_south['compound'][i]) <= -0.8 and covishield_south['compound'][i] >= -1:
        covishield_south['sentiment'][i] = 'Strong Negative'
    # Neutral Category
    else:
        covishield_south['sentiment'][i] = 'Neutral'
# Out:
# <ipython-input-148-ad849abc8fac>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_south['sentiment'][i] = 'Weak Negative'
# <ipython-input-148-ad849abc8fac>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_south['sentiment'][i] = 'Weak Positive'
# <ipython-input-148-ad849abc8fac>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_south['sentiment'][i] = 'Strong Negative'
# <ipython-input-148-ad849abc8fac>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_south['sentiment'][i] = 'Neutral'
# <ipython-input-148-ad849abc8fac>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_south['sentiment'][i] = 'Strong Positive'

# %%
#Head of dataframe after 'sentiment' column
covishield_south.head()
# Out:
#       user_location     tweet_created_at  \
# 0         bangalore  2021-04-18 12:49:53
# 1  Bengaluru, India  2021-04-18 12:41:06
# 2           chennai  2021-04-18 12:14:46
# 3         Bangalore  2021-04-18 12:01:31
# 4           chennai  2021-04-18 11:58:46
#
#                                           tweet_text  \
# 0  @amitkr12jan @iAsura_ Health Workers who were ...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2  @Arunaurs @DrJoyeeta @OmairTAhmad @devangshuda...
# 3  @cspramesh Dr Pramesh, thank you for your thre...
# 4  @SerumInstIndia @PMOIndia \nreminder call from...
#
#                                          tweet_clean  \
# 0    Health Workers who were already vaccinated i...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2            But GoI yet to respond to    s reque...
# 3   Dr Pramesh thank you for your thread  But I n...
# 4     reminder call from hospital for 2nd dose co...
#
#                                               scores  compound  \
# 0  {'neg': 0.171, 'neu': 0.743, 'pos': 0.086, 'co...   -0.6648
# 1  {'neg': 0.042, 'neu': 0.897, 'pos': 0.061, 'co...    0.2500
# 2  {'neg': 0.0, 'neu': 0.921, 'pos': 0.079, 'comp...    0.3612
# 3  {'neg': 0.06, 'neu': 0.797, 'pos': 0.143, 'com...    0.4588
# 4  {'neg': 0.24, 'neu': 0.76, 'pos': 0.0, 'compou...   -0.8678
#
#          sentiment
# 0    Weak Negative
# 1    Weak Positive
# 2    Weak Positive
# 3    Weak Positive
# 4  Strong Negative

# %%
# Different sentiments category
covishield_south['sentiment'].value_counts()
# Out:
# Weak Positive      189
# Neutral            142
# Weak Negative      108
# Strong Positive     20
# Strong Negative      4
# Name: sentiment, dtype: int64

# %%
# Percentage of Above Different Sentiments Category for Visualisation

for i in range(len(covishield_south['sentiment'].value_counts())):
    percentage = covishield_south['sentiment'].value_counts()[i] / len(covishield_south)
    print(covishield_south['sentiment'].value_counts().index[i], round(percentage*100,2),"%", "rounded to",round(percentage*100),"%")
# Out:
# Weak Positive 40.82 % rounded to 41 %
# Neutral 30.67 % rounded to 31 %
# Weak Negative 23.33 % rounded to 23 %
# Strong Positive 4.32 % rounded to 4 %
# Strong Negative 0.86 % rounded to 1 %

# %% [markdown]
# ### North-East Wise

# %%
#Reading CSV file
covishield_northeast = pd.read_csv('covishield_northeast_clean_tweets.csv')

# %%
#Head of dataframe
covishield_northeast.head()
# Out:
#       user_location  tweet_created_at  \
# 0          Guwahati  18-04-2021 08:55
# 1          Guwahati  18-04-2021 05:53
# 2      Assam, India  18-04-2021 05:00
# 3   Guwahati, India  18-04-2021 02:14
# 4  Bhagalpur, India  17-04-2021 15:28
#
#                                           tweet_text  \
# 0  Inspite of completed the full dose of Covishie...
# 1  hello @BharatBiotech @SerumInstIndia please st...
# 2  @nath_ngatey @nhm_assam @himantabiswa @pradip ...
# 3  @amardeepphukan No we are giving Covishield va...
# 4  @drnitinyashas Sir how effective is first dose...
#
#                                          tweet_clean
# 0  Inspite of completed the full dose of Covishie...
# 1  hello   please start the production I will pay...
# 2      Got 2nd Dose of  Covishield vaccine today ...
# 3        No we are giving Covishield vaccine at Gmch
# 4   Sir how effective is first dose I took my fir...

# %% [markdown]
# ### Sentiment Analysis

# %%
#Finding Polarity scores on tweet

sid.polarity_scores(covishield_northeast['tweet_clean'][1])
#The compound scores of 0-1 is positive, 0 is for neutral, -0 to -1 for negative.
# Out:
# {'neg': 0.194, 'neu': 0.732, 'pos': 0.073, 'compound': -0.5859}

# %%
#Creating Scores column to record polarity scores of tweet_clean column by lambda function.

covishield_northeast['scores']=covishield_northeast['tweet_clean'].apply(lambda tweet_clean:sid.polarity_scores(tweet_clean))

# %%
#Head of Dataframe after scores column
covishield_northeast.head()
# Out:
#       user_location  tweet_created_at  \
# 0          Guwahati  18-04-2021 08:55
# 1          Guwahati  18-04-2021 05:53
# 2      Assam, India  18-04-2021 05:00
# 3   Guwahati, India  18-04-2021 02:14
# 4  Bhagalpur, India  17-04-2021 15:28
#
#                                           tweet_text  \
# 0  Inspite of completed the full dose of Covishie...
# 1  hello @BharatBiotech @SerumInstIndia please st...
# 2  @nath_ngatey @nhm_assam @himantabiswa @pradip ...
# 3  @amardeepphukan No we are giving Covishield va...
# 4  @drnitinyashas Sir how effective is first dose...
#
#                                          tweet_clean  \
# 0  Inspite of completed the full dose of Covishie...
# 1  hello   please start the production I will pay...
# 2      Got 2nd Dose of  Covishield vaccine today ...
# 3        No we are giving Covishield vaccine at Gmch
# 4   Sir how effective is first dose I took my fir...
#
#                                               scores
# 0  {'neg': 0.101, 'neu': 0.899, 'pos': 0.0, 'comp...
# 1  {'neg': 0.194, 'neu': 0.732, 'pos': 0.073, 'co...
# 2  {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'comp...
# 3  {'neg': 0.208, 'neu': 0.566, 'pos': 0.226, 'co...
# 4  {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'comp...

# %%
#Creating Compound column by retrieving compound from dictionary of scores.

covishield_northeast['compound']=covishield_northeast['scores'].apply(lambda d:d['compound'])

# %%
#Head of Dataframe after getting Compount Score
covishield_northeast.head()
# Out:
#       user_location  tweet_created_at  \
# 0          Guwahati  18-04-2021 08:55
# 1          Guwahati  18-04-2021 05:53
# 2      Assam, India  18-04-2021 05:00
# 3   Guwahati, India  18-04-2021 02:14
# 4  Bhagalpur, India  17-04-2021 15:28
#
#                                           tweet_text  \
# 0  Inspite of completed the full dose of Covishie...
# 1  hello @BharatBiotech @SerumInstIndia please st...
# 2  @nath_ngatey @nhm_assam @himantabiswa @pradip ...
# 3  @amardeepphukan No we are giving Covishield va...
# 4  @drnitinyashas Sir how effective is first dose...
#
#                                          tweet_clean  \
# 0  Inspite of completed the full dose of Covishie...
# 1  hello   please start the production I will pay...
# 2      Got 2nd Dose of  Covishield vaccine today ...
# 3        No we are giving Covishield vaccine at Gmch
# 4   Sir how effective is first dose I took my fir...
#
#                                               scores  compound
# 0  {'neg': 0.101, 'neu': 0.899, 'pos': 0.0, 'comp...   -0.4019
# 1  {'neg': 0.194, 'neu': 0.732, 'pos': 0.073, 'co...   -0.5859
# 2  {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'comp...    0.4404
# 3  {'neg': 0.208, 'neu': 0.566, 'pos': 0.226, 'co...    0.0516
# 4  {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'comp...    0.4767

# %%
#Creating Sentiments Subdivision Category from the Compound score

covishield_northeast['sentiment'] = 'Nan'
for i in range(len(covishield_northeast)):
    # Weak Positive Category
    if(covishield_northeast['compound'][i] > 0 and covishield_northeast['compound'][i] < 0.8):
        covishield_northeast['sentiment'][i] = 'Weak Positive'
    # Strong Positive Category
    elif(covishield_northeast['compound'][i]) >= 0.8 and covishield_northeast['compound'][i] <= 1:
        covishield_northeast['sentiment'][i] = 'Strong Positive'
    # Weak Negative Category
    elif(covishield_northeast['compound'][i] < 0 and covishield_northeast['compound'][i] > -0.8):
        covishield_northeast['sentiment'][i] = 'Weak Negative'
    # Strong Negative Category
    elif(covishield_northeast['compound'][i]) <= -0.8 and covishield_northeast['compound'][i] >= -1:
        covishield_northeast['sentiment'][i] = 'Strong Negative'
    # Neutral Category
    else:
        covishield_northeast['sentiment'][i] = 'Neutral'
# Out:
# <ipython-input-158-d76a291756d0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_northeast['sentiment'][i] = 'Weak Negative'
# <ipython-input-158-d76a291756d0>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_northeast['sentiment'][i] = 'Weak Positive'
# <ipython-input-158-d76a291756d0>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_northeast['sentiment'][i] = 'Neutral'
# <ipython-input-158-d76a291756d0>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covishield_northeast['sentiment'][i] = 'Strong Positive'

# %%
#Head of dataframe after 'sentiment' column
covishield_northeast.head()
# Out:
#       user_location  tweet_created_at  \
# 0          Guwahati  18-04-2021 08:55
# 1          Guwahati  18-04-2021 05:53
# 2      Assam, India  18-04-2021 05:00
# 3   Guwahati, India  18-04-2021 02:14
# 4  Bhagalpur, India  17-04-2021 15:28
#
#                                           tweet_text  \
# 0  Inspite of completed the full dose of Covishie...
# 1  hello @BharatBiotech @SerumInstIndia please st...
# 2  @nath_ngatey @nhm_assam @himantabiswa @pradip ...
# 3  @amardeepphukan No we are giving Covishield va...
# 4  @drnitinyashas Sir how effective is first dose...
#
#                                          tweet_clean  \
# 0  Inspite of completed the full dose of Covishie...
# 1  hello   please start the production I will pay...
# 2      Got 2nd Dose of  Covishield vaccine today ...
# 3        No we are giving Covishield vaccine at Gmch
# 4   Sir how effective is first dose I took my fir...
#
#                                               scores  compound      sentiment
# 0  {'neg': 0.101, 'neu': 0.899, 'pos': 0.0, 'comp...   -0.4019  Weak Negative
# 1  {'neg': 0.194, 'neu': 0.732, 'pos': 0.073, 'co...   -0.5859  Weak Negative
# 2  {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'comp...    0.4404  Weak Positive
# 3  {'neg': 0.208, 'neu': 0.566, 'pos': 0.226, 'co...    0.0516  Weak Positive
# 4  {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'comp...    0.4767  Weak Positive

# %%
# Different sentiments category 
covishield_northeast['sentiment'].value_counts()
# Out:
# Weak Positive      23
# Neutral            22
# Weak Negative      10
# Strong Positive     2
# Name: sentiment, dtype: int64

# %%
# Percentage of Above Different Sentiments Category for Visualisation

for i in range(len(covishield_northeast['sentiment'].value_counts())):
    percentage = covishield_northeast['sentiment'].value_counts()[i] / len(covishield_northeast)
    print(covishield_northeast['sentiment'].value_counts().index[i], round(percentage*100,2),"%", "rounded to",round(percentage*100),"%")
# Out:
# Weak Positive 40.35 % rounded to 40 %
# Neutral 38.6 % rounded to 39 %
# Weak Negative 17.54 % rounded to 18 %
# Strong Positive 3.51 % rounded to 4 %

# %% [markdown]
# ## Covaxin (Zonal Wise)

# %% [markdown]
# ### North Wise

# %%
#Reading CSV file
covaxin_north = pd.read_csv('covaxin_north_clean_tweets.csv')

# %%
#Head of dataframe
covaxin_north.head()
# Out:
#       user_location  tweet_created_at  \
# 0             Delhi  18-04-2021 13:21
# 1  Ghaziabad, India  18-04-2021 13:07
# 2  New Delhi, India  18-04-2021 12:53
# 3         New Delhi  18-04-2021 12:43
# 4             Noida  18-04-2021 12:12
#
#                                           tweet_text  \
# 0  Mamata didi is covishield and covaxin combined...
# 1  @sandesh_ic @iAsura_ &amp; In my family 2 docs...
# 2  @ShekharGupta 1/2\nYes, more brand vaccine pro...
# 3  @cloudnikki @ArvinderSoin @freedoomer in delhi...
# 4  Both Covishield and Covaxin have been deemed s...
#
#                                          tweet_clean
# 0  Mamata didi is covishield and covaxin combined...
# 1     amp  In my family 2 docs have got Covaxin  ...
# 2   1 2 Yes more brand vaccine production is very...
# 3                     in delhi we dont have covaxin
# 4  Both Covishield and Covaxin have been deemed s...

# %% [markdown]
# ### Sentiment Analysis

# %%
#Finding Polarity scores on tweet

sid.polarity_scores(covaxin_north['tweet_clean'][1])
#The compound scores of 0-1 is positive, 0 is for neutral, -0 to -1 for negative.
# Out:
# {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'compound': 0.3875}

# %%
#Creating Scores column to record polarity scores of tweet_clean column by lambda function.

covaxin_north['scores']=covaxin_north['tweet_clean'].apply(lambda tweet_clean:sid.polarity_scores(tweet_clean))

# %%
#Head of Dataframe after scores column
covaxin_north.head()
# Out:
#       user_location  tweet_created_at  \
# 0             Delhi  18-04-2021 13:21
# 1  Ghaziabad, India  18-04-2021 13:07
# 2  New Delhi, India  18-04-2021 12:53
# 3         New Delhi  18-04-2021 12:43
# 4             Noida  18-04-2021 12:12
#
#                                           tweet_text  \
# 0  Mamata didi is covishield and covaxin combined...
# 1  @sandesh_ic @iAsura_ &amp; In my family 2 docs...
# 2  @ShekharGupta 1/2\nYes, more brand vaccine pro...
# 3  @cloudnikki @ArvinderSoin @freedoomer in delhi...
# 4  Both Covishield and Covaxin have been deemed s...
#
#                                          tweet_clean  \
# 0  Mamata didi is covishield and covaxin combined...
# 1     amp  In my family 2 docs have got Covaxin  ...
# 2   1 2 Yes more brand vaccine production is very...
# 3                     in delhi we dont have covaxin
# 4  Both Covishield and Covaxin have been deemed s...
#
#                                               scores
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'comp...
# 2  {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'comp...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 0.921, 'pos': 0.079, 'comp...

# %%
#Creating Compound column by retrieving compound from dictionary of scores.

covaxin_north['compound']=covaxin_north['scores'].apply(lambda d:d['compound'])

# %%
#Head of Dataframe after getting Compount Score
covaxin_north.head()
# Out:
#       user_location  tweet_created_at  \
# 0             Delhi  18-04-2021 13:21
# 1  Ghaziabad, India  18-04-2021 13:07
# 2  New Delhi, India  18-04-2021 12:53
# 3         New Delhi  18-04-2021 12:43
# 4             Noida  18-04-2021 12:12
#
#                                           tweet_text  \
# 0  Mamata didi is covishield and covaxin combined...
# 1  @sandesh_ic @iAsura_ &amp; In my family 2 docs...
# 2  @ShekharGupta 1/2\nYes, more brand vaccine pro...
# 3  @cloudnikki @ArvinderSoin @freedoomer in delhi...
# 4  Both Covishield and Covaxin have been deemed s...
#
#                                          tweet_clean  \
# 0  Mamata didi is covishield and covaxin combined...
# 1     amp  In my family 2 docs have got Covaxin  ...
# 2   1 2 Yes more brand vaccine production is very...
# 3                     in delhi we dont have covaxin
# 4  Both Covishield and Covaxin have been deemed s...
#
#                                               scores  compound
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 1  {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'comp...    0.3875
# 2  {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'comp...    0.6124
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 4  {'neg': 0.0, 'neu': 0.921, 'pos': 0.079, 'comp...    0.4404

# %%
#Creating Sentiments Subdivision Category from the Compound score

covaxin_north['sentiment'] = 'Nan'
for i in range(len(covaxin_north)):
    # Weak Positive Category
    if(covaxin_north['compound'][i] > 0 and covaxin_north['compound'][i] < 0.8):
        covaxin_north['sentiment'][i] = 'Weak Positive'
    # Strong Positive Category
    elif(covaxin_north['compound'][i]) >= 0.8 and covaxin_north['compound'][i] <= 1:
        covaxin_north['sentiment'][i] = 'Strong Positive'
    # Weak Negative Category
    elif(covaxin_north['compound'][i] < 0 and covaxin_north['compound'][i] > -0.8):
        covaxin_north['sentiment'][i] = 'Weak Negative'
    # Strong Negative Category
    elif(covaxin_north['compound'][i]) <= -0.8 and covaxin_north['compound'][i] >= -1:
        covaxin_north['sentiment'][i] = 'Strong Negative'
    # Neutral Category
    else:
        covaxin_north['sentiment'][i] = 'Neutral'
# Out:
# <ipython-input-168-93b7cb5703e8>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_north['sentiment'][i] = 'Neutral'
# <ipython-input-168-93b7cb5703e8>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_north['sentiment'][i] = 'Weak Positive'
# <ipython-input-168-93b7cb5703e8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_north['sentiment'][i] = 'Weak Negative'
# <ipython-input-168-93b7cb5703e8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_north['sentiment'][i] = 'Strong Positive'
# <ipython-input-168-93b7cb5703e8>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_north['sentiment'][i] = 'Strong Negative'

# %%
#Head of dataframe after 'sentiment' column
covaxin_north.head()
# Out:
#       user_location  tweet_created_at  \
# 0             Delhi  18-04-2021 13:21
# 1  Ghaziabad, India  18-04-2021 13:07
# 2  New Delhi, India  18-04-2021 12:53
# 3         New Delhi  18-04-2021 12:43
# 4             Noida  18-04-2021 12:12
#
#                                           tweet_text  \
# 0  Mamata didi is covishield and covaxin combined...
# 1  @sandesh_ic @iAsura_ &amp; In my family 2 docs...
# 2  @ShekharGupta 1/2\nYes, more brand vaccine pro...
# 3  @cloudnikki @ArvinderSoin @freedoomer in delhi...
# 4  Both Covishield and Covaxin have been deemed s...
#
#                                          tweet_clean  \
# 0  Mamata didi is covishield and covaxin combined...
# 1     amp  In my family 2 docs have got Covaxin  ...
# 2   1 2 Yes more brand vaccine production is very...
# 3                     in delhi we dont have covaxin
# 4  Both Covishield and Covaxin have been deemed s...
#
#                                               scores  compound      sentiment
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        Neutral
# 1  {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'comp...    0.3875  Weak Positive
# 2  {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'comp...    0.6124  Weak Positive
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        Neutral
# 4  {'neg': 0.0, 'neu': 0.921, 'pos': 0.079, 'comp...    0.4404  Weak Positive

# %%
# Different sentiments category
covaxin_north['sentiment'].value_counts()
# Out:
# Weak Positive      325
# Neutral            192
# Weak Negative      163
# Strong Positive     34
# Strong Negative     10
# Name: sentiment, dtype: int64

# %%
# Percentage of Above Different Sentiments Category for Visualisation

for i in range(len(covaxin_north['sentiment'].value_counts())):
    percentage = covaxin_north['sentiment'].value_counts()[i] / len(covaxin_north)
    print(covaxin_north['sentiment'].value_counts().index[i], round(percentage*100,2),"%", "rounded to",round(percentage*100),"%")
# Out:
# Weak Positive 44.89 % rounded to 45 %
# Neutral 26.52 % rounded to 27 %
# Weak Negative 22.51 % rounded to 23 %
# Strong Positive 4.7 % rounded to 5 %
# Strong Negative 1.38 % rounded to 1 %

# %% [markdown]
# ### East Wise

# %%
#Reading CSV file
covaxin_east = pd.read_csv('covaxin_east_clean_tweets.csv')

# %%
#Head of dataframe
covaxin_east.head()
# Out:
#           user_location  tweet_created_at  \
# 0             Himalayas  18-04-2021 12:37
# 1               Lucknow  18-04-2021 11:08
# 2        Lucknow, India  18-04-2021 10:17
# 3  Uttar Pradesh, India  18-04-2021 06:44
# 4          Patna, India  18-04-2021 06:39
#
#                                           tweet_text  \
# 0  @ShekharGupta Also a mirror to you the way u r...
# 1  @aarohi_vns Data of what vaccine 1st dose was ...
# 2  @CovidIndiaSeva atleast provide second dose of...
# 3  Mode of transmission.\nAir borne/surface?\nNot...
# 4  People vaccinated with 2doses #covaxin  #covis...
#
#                                          tweet_clean
# 0   Also a mirror to you the way u ran propaganda...
# 1   Data of what vaccine 1st dose was taken  cova...
# 2   atleast provide second dose of covaxin  this ...
# 3  Mode of transmission  Air borne surface  Not s...
# 4  People vaccinated with 2doses  covaxin   covis...

# %% [markdown]
# ### Sentiment Analysis

# %%
#Finding Polarity scores on tweet

sid.polarity_scores(covaxin_east['tweet_clean'][1])
#The compound scores of 0-1 is positive, 0 is for neutral, -0 to -1 for negative.
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
#Creating Scores column to record polarity scores of tweet_clean column by lambda function.

covaxin_east['scores']=covaxin_east['tweet_clean'].apply(lambda tweet_clean:sid.polarity_scores(tweet_clean))

# %%
#Head of Dataframe after scores column
covaxin_east.head()
# Out:
#           user_location  tweet_created_at  \
# 0             Himalayas  18-04-2021 12:37
# 1               Lucknow  18-04-2021 11:08
# 2        Lucknow, India  18-04-2021 10:17
# 3  Uttar Pradesh, India  18-04-2021 06:44
# 4          Patna, India  18-04-2021 06:39
#
#                                           tweet_text  \
# 0  @ShekharGupta Also a mirror to you the way u r...
# 1  @aarohi_vns Data of what vaccine 1st dose was ...
# 2  @CovidIndiaSeva atleast provide second dose of...
# 3  Mode of transmission.\nAir borne/surface?\nNot...
# 4  People vaccinated with 2doses #covaxin  #covis...
#
#                                          tweet_clean  \
# 0   Also a mirror to you the way u ran propaganda...
# 1   Data of what vaccine 1st dose was taken  cova...
# 2   atleast provide second dose of covaxin  this ...
# 3  Mode of transmission  Air borne surface  Not s...
# 4  People vaccinated with 2doses  covaxin   covis...
#
#                                               scores
# 0  {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'comp...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'comp...
# 3  {'neg': 0.211, 'neu': 0.789, 'pos': 0.0, 'comp...
# 4  {'neg': 0.276, 'neu': 0.695, 'pos': 0.029, 'co...

# %%
#Creating Compound column by retrieving compound from dictionary of scores

covaxin_east['compound']=covaxin_east['scores'].apply(lambda d:d['compound'])

# %%
#Head of Dataframe after getting Compount Score
covaxin_east.head()
# Out:
#           user_location  tweet_created_at  \
# 0             Himalayas  18-04-2021 12:37
# 1               Lucknow  18-04-2021 11:08
# 2        Lucknow, India  18-04-2021 10:17
# 3  Uttar Pradesh, India  18-04-2021 06:44
# 4          Patna, India  18-04-2021 06:39
#
#                                           tweet_text  \
# 0  @ShekharGupta Also a mirror to you the way u r...
# 1  @aarohi_vns Data of what vaccine 1st dose was ...
# 2  @CovidIndiaSeva atleast provide second dose of...
# 3  Mode of transmission.\nAir borne/surface?\nNot...
# 4  People vaccinated with 2doses #covaxin  #covis...
#
#                                          tweet_clean  \
# 0   Also a mirror to you the way u ran propaganda...
# 1   Data of what vaccine 1st dose was taken  cova...
# 2   atleast provide second dose of covaxin  this ...
# 3  Mode of transmission  Air borne surface  Not s...
# 4  People vaccinated with 2doses  covaxin   covis...
#
#                                               scores  compound
# 0  {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'comp...   -0.6486
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 2  {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'comp...    0.2023
# 3  {'neg': 0.211, 'neu': 0.789, 'pos': 0.0, 'comp...   -0.5975
# 4  {'neg': 0.276, 'neu': 0.695, 'pos': 0.029, 'co...   -0.9001

# %%
#Creating Sentiments Subdivision Category from the Compound score

covaxin_east['sentiment'] = 'Nan'
for i in range(len(covaxin_east)):
    # Weak Positive Category
    if(covaxin_east['compound'][i] > 0 and covaxin_east['compound'][i] < 0.8):
        covaxin_east['sentiment'][i] = 'Weak Positive'
    # Strong Positive Category
    elif(covaxin_east['compound'][i]) >= 0.8 and covaxin_east['compound'][i] <= 1:
        covaxin_east['sentiment'][i] = 'Strong Positive'
    # Weak Negative Category
    elif(covaxin_east['compound'][i] < 0 and covaxin_east['compound'][i] > -0.8):
        covaxin_east['sentiment'][i] = 'Weak Negative'
    # Strong Negative Category
    elif(covaxin_east['compound'][i]) <= -0.8 and covaxin_east['compound'][i] >= -1:
        covaxin_east['sentiment'][i] = 'Strong Negative'
    # Neutral Category
    else:
        covaxin_east['sentiment'][i] = 'Neutral'
# Out:
# <ipython-input-178-79728f65c450>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_east['sentiment'][i] = 'Weak Negative'
# <ipython-input-178-79728f65c450>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_east['sentiment'][i] = 'Neutral'
# <ipython-input-178-79728f65c450>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_east['sentiment'][i] = 'Weak Positive'
# <ipython-input-178-79728f65c450>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_east['sentiment'][i] = 'Strong Negative'
# <ipython-input-178-79728f65c450>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_east['sentiment'][i] = 'Strong Positive'

# %%
#Head of dataframe after 'sentiment' column
covaxin_east.head()
# Out:
#           user_location  tweet_created_at  \
# 0             Himalayas  18-04-2021 12:37
# 1               Lucknow  18-04-2021 11:08
# 2        Lucknow, India  18-04-2021 10:17
# 3  Uttar Pradesh, India  18-04-2021 06:44
# 4          Patna, India  18-04-2021 06:39
#
#                                           tweet_text  \
# 0  @ShekharGupta Also a mirror to you the way u r...
# 1  @aarohi_vns Data of what vaccine 1st dose was ...
# 2  @CovidIndiaSeva atleast provide second dose of...
# 3  Mode of transmission.\nAir borne/surface?\nNot...
# 4  People vaccinated with 2doses #covaxin  #covis...
#
#                                          tweet_clean  \
# 0   Also a mirror to you the way u ran propaganda...
# 1   Data of what vaccine 1st dose was taken  cova...
# 2   atleast provide second dose of covaxin  this ...
# 3  Mode of transmission  Air borne surface  Not s...
# 4  People vaccinated with 2doses  covaxin   covis...
#
#                                               scores  compound  \
# 0  {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'comp...   -0.6486
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 2  {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'comp...    0.2023
# 3  {'neg': 0.211, 'neu': 0.789, 'pos': 0.0, 'comp...   -0.5975
# 4  {'neg': 0.276, 'neu': 0.695, 'pos': 0.029, 'co...   -0.9001
#
#          sentiment
# 0    Weak Negative
# 1          Neutral
# 2    Weak Positive
# 3    Weak Negative
# 4  Strong Negative

# %%
# Different sentiments category 
covaxin_east['sentiment'].value_counts()
# Out:
# Weak Positive      45
# Weak Negative      31
# Neutral            30
# Strong Positive     8
# Strong Negative     1
# Name: sentiment, dtype: int64

# %%
# Percentage of Above Different Sentiments Category for Visualisation

for i in range(len(covaxin_east['sentiment'].value_counts())):
    percentage = covaxin_east['sentiment'].value_counts()[i] / len(covaxin_east)
    print(covaxin_east['sentiment'].value_counts().index[i], round(percentage*100,2),"%", "rounded to",round(percentage*100),"%")
# Out:
# Weak Positive 39.13 % rounded to 39 %
# Weak Negative 26.96 % rounded to 27 %
# Neutral 26.09 % rounded to 26 %
# Strong Positive 6.96 % rounded to 7 %
# Strong Negative 0.87 % rounded to 1 %

# %% [markdown]
# ### West Wise

# %%
#Reading CSV file
covaxin_west = pd.read_csv('covaxin_west_clean_tweets.csv')

# %%
#Head of dataframe
covaxin_west.head()
# Out:
#            user_location  tweet_created_at  \
# 0                  India  18-04-2021 13:06
# 1                 Bharat  18-04-2021 12:54
# 2                  India  18-04-2021 12:53
# 3  Madhya Pradesh, India  18-04-2021 12:52
# 4       Ahmadabad, India  18-04-2021 12:27
#
#                                           tweet_text  \
# 0  Heard rumors about Covid-19 vaccine ( Covishei...
# 1  https://t.co/GGvYPeVUPS\nShameful.. #IndiaFigh...
# 2            @satishacharya Covaxin or covieshield ?
# 3  @prik1408 @DipshikhaGhosh Can't Comment On The...
# 4  @BagatiSoham @SupriyaShrinate @narendramodi @I...
#
#                                          tweet_clean
# 0  Heard rumors about Covid 19 vaccine   Covishei...
# 1                      Shameful    IndiaFightsCorona
# 2                           Covaxin or covieshield
# 3    Can t Comment On The Efficacy Or Comparison ...
# 4       Will you care to read whole article  If n...

# %% [markdown]
# ### Sentiment Analysis

# %%
#Finding Polarity scores on tweet

sid.polarity_scores(covaxin_west['tweet_clean'][1])
#The compound scores of 0-1 is positive, 0 is for neutral, -0 to -1 for negative.
# Out:
# {'neg': 0.762, 'neu': 0.238, 'pos': 0.0, 'compound': -0.4939}

# %%
#Creating Scores column to record polarity scores of tweet_clean column by lambda function.

covaxin_west['scores']=covaxin_west['tweet_clean'].apply(lambda tweet_clean:sid.polarity_scores(tweet_clean))

# %%
#Head of Dataframe after scores column
covaxin_west.head()
# Out:
#            user_location  tweet_created_at  \
# 0                  India  18-04-2021 13:06
# 1                 Bharat  18-04-2021 12:54
# 2                  India  18-04-2021 12:53
# 3  Madhya Pradesh, India  18-04-2021 12:52
# 4       Ahmadabad, India  18-04-2021 12:27
#
#                                           tweet_text  \
# 0  Heard rumors about Covid-19 vaccine ( Covishei...
# 1  https://t.co/GGvYPeVUPS\nShameful.. #IndiaFigh...
# 2            @satishacharya Covaxin or covieshield ?
# 3  @prik1408 @DipshikhaGhosh Can't Comment On The...
# 4  @BagatiSoham @SupriyaShrinate @narendramodi @I...
#
#                                          tweet_clean  \
# 0  Heard rumors about Covid 19 vaccine   Covishei...
# 1                      Shameful    IndiaFightsCorona
# 2                           Covaxin or covieshield
# 3    Can t Comment On The Efficacy Or Comparison ...
# 4       Will you care to read whole article  If n...
#
#                                               scores
# 0  {'neg': 0.089, 'neu': 0.801, 'pos': 0.111, 'co...
# 1  {'neg': 0.762, 'neu': 0.238, 'pos': 0.0, 'comp...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'comp...
# 4  {'neg': 0.0, 'neu': 0.862, 'pos': 0.138, 'comp...

# %%
#Creating Compound column by retrieving compound from dictionary of scores.

covaxin_west['compound']=covaxin_west['scores'].apply(lambda d:d['compound'])

# %%
#Head of Dataframe after getting Compount Score
covaxin_west.head()
# Out:
#            user_location  tweet_created_at  \
# 0                  India  18-04-2021 13:06
# 1                 Bharat  18-04-2021 12:54
# 2                  India  18-04-2021 12:53
# 3  Madhya Pradesh, India  18-04-2021 12:52
# 4       Ahmadabad, India  18-04-2021 12:27
#
#                                           tweet_text  \
# 0  Heard rumors about Covid-19 vaccine ( Covishei...
# 1  https://t.co/GGvYPeVUPS\nShameful.. #IndiaFigh...
# 2            @satishacharya Covaxin or covieshield ?
# 3  @prik1408 @DipshikhaGhosh Can't Comment On The...
# 4  @BagatiSoham @SupriyaShrinate @narendramodi @I...
#
#                                          tweet_clean  \
# 0  Heard rumors about Covid 19 vaccine   Covishei...
# 1                      Shameful    IndiaFightsCorona
# 2                           Covaxin or covieshield
# 3    Can t Comment On The Efficacy Or Comparison ...
# 4       Will you care to read whole article  If n...
#
#                                               scores  compound
# 0  {'neg': 0.089, 'neu': 0.801, 'pos': 0.111, 'co...    0.1451
# 1  {'neg': 0.762, 'neu': 0.238, 'pos': 0.0, 'comp...   -0.4939
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 3  {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'comp...    0.5106
# 4  {'neg': 0.0, 'neu': 0.862, 'pos': 0.138, 'comp...    0.4939

# %%
#Creating Sentiments Subdivision Category from the Compound score
covaxin_west['sentiment'] = 'Nan'
for i in range(len(covaxin_west)):
    # Weak Positive Category
    if(covaxin_west['compound'][i] > 0 and covaxin_west['compound'][i] < 0.8):
        covaxin_west['sentiment'][i] = 'Weak Positive'
    # Strong Positive Category
    elif(covaxin_west['compound'][i]) >= 0.8 and covaxin_west['compound'][i] <= 1:
        covaxin_west['sentiment'][i] = 'Strong Positive'
    # Weak Negative Category
    elif(covaxin_west['compound'][i] < 0 and covaxin_west['compound'][i] > -0.8):
        covaxin_west['sentiment'][i] = 'Weak Negative'
    # Strong Negative Category
    elif(covaxin_west['compound'][i]) <= -0.8 and covaxin_west['compound'][i] >= -1:
        covaxin_west['sentiment'][i] = 'Strong Negative'
    # Neutral Category
    else:
        covaxin_west['sentiment'][i] = 'Neutral'
# Out:
# <ipython-input-188-4a85ccdf5c9c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_west['sentiment'][i] = 'Weak Positive'
# <ipython-input-188-4a85ccdf5c9c>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_west['sentiment'][i] = 'Weak Negative'
# <ipython-input-188-4a85ccdf5c9c>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_west['sentiment'][i] = 'Neutral'
# <ipython-input-188-4a85ccdf5c9c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_west['sentiment'][i] = 'Strong Positive'
# <ipython-input-188-4a85ccdf5c9c>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_west['sentiment'][i] = 'Strong Negative'

# %%
#Head of dataframe after 'sentiment' column
covaxin_west.head()
# Out:
#            user_location  tweet_created_at  \
# 0                  India  18-04-2021 13:06
# 1                 Bharat  18-04-2021 12:54
# 2                  India  18-04-2021 12:53
# 3  Madhya Pradesh, India  18-04-2021 12:52
# 4       Ahmadabad, India  18-04-2021 12:27
#
#                                           tweet_text  \
# 0  Heard rumors about Covid-19 vaccine ( Covishei...
# 1  https://t.co/GGvYPeVUPS\nShameful.. #IndiaFigh...
# 2            @satishacharya Covaxin or covieshield ?
# 3  @prik1408 @DipshikhaGhosh Can't Comment On The...
# 4  @BagatiSoham @SupriyaShrinate @narendramodi @I...
#
#                                          tweet_clean  \
# 0  Heard rumors about Covid 19 vaccine   Covishei...
# 1                      Shameful    IndiaFightsCorona
# 2                           Covaxin or covieshield
# 3    Can t Comment On The Efficacy Or Comparison ...
# 4       Will you care to read whole article  If n...
#
#                                               scores  compound      sentiment
# 0  {'neg': 0.089, 'neu': 0.801, 'pos': 0.111, 'co...    0.1451  Weak Positive
# 1  {'neg': 0.762, 'neu': 0.238, 'pos': 0.0, 'comp...   -0.4939  Weak Negative
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        Neutral
# 3  {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'comp...    0.5106  Weak Positive
# 4  {'neg': 0.0, 'neu': 0.862, 'pos': 0.138, 'comp...    0.4939  Weak Positive

# %%
# Different sentiments category 
covaxin_west['sentiment'].value_counts()
# Out:
# Weak Positive      469
# Neutral            377
# Weak Negative      286
# Strong Positive     42
# Strong Negative     22
# Name: sentiment, dtype: int64

# %%
# Percentage of Above Different Sentiments Category for Visualisation

for i in range(len(covaxin_west['sentiment'].value_counts())):
    percentage = covaxin_west['sentiment'].value_counts()[i] / len(covaxin_west)
    print(covaxin_west['sentiment'].value_counts().index[i], round(percentage*100,2),"%", "rounded to",round(percentage*100),"%")
# Out:
# Weak Positive 39.21 % rounded to 39 %
# Neutral 31.52 % rounded to 32 %
# Weak Negative 23.91 % rounded to 24 %
# Strong Positive 3.51 % rounded to 4 %
# Strong Negative 1.84 % rounded to 2 %

# %% [markdown]
# ### South Wise

# %%
#Reading CSV file
covaxin_south = pd.read_csv('covaxin_south_clean_tweets.csv')

# %%
#Head of dataframe
covaxin_south.head()
# Out:
#       user_location  tweet_created_at  \
# 0         bangalore  18-04-2021 12:49
# 1  Bengaluru, India  18-04-2021 12:41
# 2         Bangalore  18-04-2021 12:40
# 3         bangalore  18-04-2021 12:27
# 4         Bangalore  18-04-2021 12:01
#
#                                           tweet_text  \
# 0  @amitkr12jan @iAsura_ Health Workers who were ...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2  @sardesairajdeep @narendramodi @PMOIndia @Indi...
# 3  @iAsura_ I strongly feel covaxin will be faile...
# 4  @cspramesh Dr Pramesh, thank you for your thre...
#
#                                          tweet_clean
# 0    Health Workers who were already vaccinated i...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2      blood is on hand of likes of u who spread ...
# 3   I strongly feel covaxin will be failed the va...
# 4   Dr Pramesh thank you for your thread  But I n...

# %% [markdown]
# ### Sentiment Analysis

# %%
#Finding Polarity scores on tweet

sid.polarity_scores(covaxin_south['tweet_clean'][1])
#The compound scores of 0-1 is positive, 0 is for neutral, -0 to -1 for negative.
# Out:
# {'neg': 0.042, 'neu': 0.897, 'pos': 0.061, 'compound': 0.25}

# %%
#Creating Scores column to record polarity scores of tweet_clean column by lambda function.

covaxin_south['scores']=covaxin_south['tweet_clean'].apply(lambda tweet_clean:sid.polarity_scores(tweet_clean))

# %%
#Head of Dataframe after scores column
covaxin_south.head()
# Out:
#       user_location  tweet_created_at  \
# 0         bangalore  18-04-2021 12:49
# 1  Bengaluru, India  18-04-2021 12:41
# 2         Bangalore  18-04-2021 12:40
# 3         bangalore  18-04-2021 12:27
# 4         Bangalore  18-04-2021 12:01
#
#                                           tweet_text  \
# 0  @amitkr12jan @iAsura_ Health Workers who were ...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2  @sardesairajdeep @narendramodi @PMOIndia @Indi...
# 3  @iAsura_ I strongly feel covaxin will be faile...
# 4  @cspramesh Dr Pramesh, thank you for your thre...
#
#                                          tweet_clean  \
# 0    Health Workers who were already vaccinated i...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2      blood is on hand of likes of u who spread ...
# 3   I strongly feel covaxin will be failed the va...
# 4   Dr Pramesh thank you for your thread  But I n...
#
#                                               scores
# 0  {'neg': 0.171, 'neu': 0.743, 'pos': 0.086, 'co...
# 1  {'neg': 0.042, 'neu': 0.897, 'pos': 0.061, 'co...
# 2  {'neg': 0.067, 'neu': 0.803, 'pos': 0.13, 'com...
# 3  {'neg': 0.188, 'neu': 0.627, 'pos': 0.185, 'co...
# 4  {'neg': 0.06, 'neu': 0.797, 'pos': 0.143, 'com...

# %%
#Creating Compound column by retrieving compound from dictionary of scores.

covaxin_south['compound']=covaxin_south['scores'].apply(lambda d:d['compound'])

# %%
#Head of Dataframe after getting Compount Score
covaxin_south.head()
# Out:
#       user_location  tweet_created_at  \
# 0         bangalore  18-04-2021 12:49
# 1  Bengaluru, India  18-04-2021 12:41
# 2         Bangalore  18-04-2021 12:40
# 3         bangalore  18-04-2021 12:27
# 4         Bangalore  18-04-2021 12:01
#
#                                           tweet_text  \
# 0  @amitkr12jan @iAsura_ Health Workers who were ...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2  @sardesairajdeep @narendramodi @PMOIndia @Indi...
# 3  @iAsura_ I strongly feel covaxin will be faile...
# 4  @cspramesh Dr Pramesh, thank you for your thre...
#
#                                          tweet_clean  \
# 0    Health Workers who were already vaccinated i...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2      blood is on hand of likes of u who spread ...
# 3   I strongly feel covaxin will be failed the va...
# 4   Dr Pramesh thank you for your thread  But I n...
#
#                                               scores  compound
# 0  {'neg': 0.171, 'neu': 0.743, 'pos': 0.086, 'co...   -0.6648
# 1  {'neg': 0.042, 'neu': 0.897, 'pos': 0.061, 'co...    0.2500
# 2  {'neg': 0.067, 'neu': 0.803, 'pos': 0.13, 'com...    0.4404
# 3  {'neg': 0.188, 'neu': 0.627, 'pos': 0.185, 'co...   -0.2760
# 4  {'neg': 0.06, 'neu': 0.797, 'pos': 0.143, 'com...    0.4588

# %%
#Creating Sentiments Subdivision Category from the Compound score

covaxin_south['sentiment'] = 'Nan'
for i in range(len(covaxin_south)):
    # Weak Positive Category
    if(covaxin_south['compound'][i] > 0 and covaxin_south['compound'][i] < 0.8):
        covaxin_south['sentiment'][i] = 'Weak Positive'
    # Strong Positive Category
    elif(covaxin_south['compound'][i]) >= 0.8 and covaxin_south['compound'][i] <= 1:
        covaxin_south['sentiment'][i] = 'Strong Positive'
    # Weak Negative Category
    elif(covaxin_south['compound'][i] < 0 and covaxin_south['compound'][i] > -0.8):
        covaxin_south['sentiment'][i] = 'Weak Negative'
    # Strong Negative Category
    elif(covaxin_south['compound'][i]) <= -0.8 and covaxin_south['compound'][i] >= -1:
        covaxin_south['sentiment'][i] = 'Strong Negative'
    # Neutral Category
    else:
        covaxin_south['sentiment'][i] = 'Neutral'
# Out:
# <ipython-input-198-e1af918d18c9>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_south['sentiment'][i] = 'Weak Negative'
# <ipython-input-198-e1af918d18c9>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_south['sentiment'][i] = 'Weak Positive'
# <ipython-input-198-e1af918d18c9>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_south['sentiment'][i] = 'Strong Positive'
# <ipython-input-198-e1af918d18c9>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_south['sentiment'][i] = 'Neutral'
# <ipython-input-198-e1af918d18c9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_south['sentiment'][i] = 'Strong Negative'

# %%
#Head of dataframe after 'sentiment' column
covaxin_south.head()
# Out:
#       user_location  tweet_created_at  \
# 0         bangalore  18-04-2021 12:49
# 1  Bengaluru, India  18-04-2021 12:41
# 2         Bangalore  18-04-2021 12:40
# 3         bangalore  18-04-2021 12:27
# 4         Bangalore  18-04-2021 12:01
#
#                                           tweet_text  \
# 0  @amitkr12jan @iAsura_ Health Workers who were ...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2  @sardesairajdeep @narendramodi @PMOIndia @Indi...
# 3  @iAsura_ I strongly feel covaxin will be faile...
# 4  @cspramesh Dr Pramesh, thank you for your thre...
#
#                                          tweet_clean  \
# 0    Health Workers who were already vaccinated i...
# 1  PM care fund brought Covishield vaccine at Rs ...
# 2      blood is on hand of likes of u who spread ...
# 3   I strongly feel covaxin will be failed the va...
# 4   Dr Pramesh thank you for your thread  But I n...
#
#                                               scores  compound      sentiment
# 0  {'neg': 0.171, 'neu': 0.743, 'pos': 0.086, 'co...   -0.6648  Weak Negative
# 1  {'neg': 0.042, 'neu': 0.897, 'pos': 0.061, 'co...    0.2500  Weak Positive
# 2  {'neg': 0.067, 'neu': 0.803, 'pos': 0.13, 'com...    0.4404  Weak Positive
# 3  {'neg': 0.188, 'neu': 0.627, 'pos': 0.185, 'co...   -0.2760  Weak Negative
# 4  {'neg': 0.06, 'neu': 0.797, 'pos': 0.143, 'com...    0.4588  Weak Positive

# %%
# Different sentiments category
covaxin_south['sentiment'].value_counts()
# Out:
# Weak Positive      259
# Weak Negative      166
# Neutral            165
# Strong Positive     28
# Strong Negative     10
# Name: sentiment, dtype: int64

# %%
# Percentage of Above Different Sentiments Category for Visualisation

for i in range(len(covaxin_south['sentiment'].value_counts())):
    percentage = covaxin_south['sentiment'].value_counts()[i] / len(covaxin_south)
    print(covaxin_south['sentiment'].value_counts().index[i], round(percentage*100,2),"%", "rounded to",round(percentage*100),"%")
# Out:
# Weak Positive 41.24 % rounded to 41 %
# Weak Negative 26.43 % rounded to 26 %
# Neutral 26.27 % rounded to 26 %
# Strong Positive 4.46 % rounded to 4 %
# Strong Negative 1.59 % rounded to 2 %

# %% [markdown]
# ### North-East Wise

# %%
#Reading CSV file
covaxin_northeast = pd.read_csv('covaxin_northeast_clean_tweets.csv')

# %%
#Head of dataframe
covaxin_northeast.head()
# Out:
#      user_location  tweet_created_at  \
# 0  Guwahati, Assam  18-04-2021 05:53
# 1  Guwahati, Assam  18-04-2021 03:17
# 2  Guwahati, India  17-04-2021 18:33
# 3  Guwahati, India  17-04-2021 16:28
# 4  Guwahati, India  17-04-2021 14:27
#
#                                           tweet_text  \
# 0  hello @BharatBiotech @SerumInstIndia please st...
# 1  To increase the supply of #COVID19Vaccine, the...
# 2  @virsanghvi Hypocrite people like you were the...
# 3  @abhijitsarma Hi Dr Abhijit are you administer...
# 4  covid-19 vaccine in assam, covaxin vs covishie...
#
#                                          tweet_clean
# 0  hello   please start the production I will pay...
# 1  To increase the supply of  COVID19Vaccine the ...
# 2   Hypocrite people like you were the biggest bo...
# 3   Hi Dr Abhijit are you administering covaxin o...
# 4   covid 19 vaccine in assam covaxin vs covishield

# %% [markdown]
# ### Sentiment Analysis

# %%
#Finding Polarity scores on tweet

sid.polarity_scores(covaxin_northeast['tweet_clean'][1])
#The compound scores of 0-1 is positive, 0 is for neutral, -0 to -1 for negative.
# Out:
# {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'compound': 0.5267}

# %%
#Creating Scores column to record polarity scores of tweet_clean column by lambda function.

covaxin_northeast['scores']=covaxin_northeast['tweet_clean'].apply(lambda tweet_clean:sid.polarity_scores(tweet_clean))

# %%
#Head of Dataframe after scores column
covaxin_northeast.head()
# Out:
#      user_location  tweet_created_at  \
# 0  Guwahati, Assam  18-04-2021 05:53
# 1  Guwahati, Assam  18-04-2021 03:17
# 2  Guwahati, India  17-04-2021 18:33
# 3  Guwahati, India  17-04-2021 16:28
# 4  Guwahati, India  17-04-2021 14:27
#
#                                           tweet_text  \
# 0  hello @BharatBiotech @SerumInstIndia please st...
# 1  To increase the supply of #COVID19Vaccine, the...
# 2  @virsanghvi Hypocrite people like you were the...
# 3  @abhijitsarma Hi Dr Abhijit are you administer...
# 4  covid-19 vaccine in assam, covaxin vs covishie...
#
#                                          tweet_clean  \
# 0  hello   please start the production I will pay...
# 1  To increase the supply of  COVID19Vaccine the ...
# 2   Hypocrite people like you were the biggest bo...
# 3   Hi Dr Abhijit are you administering covaxin o...
# 4   covid 19 vaccine in assam covaxin vs covishield
#
#                                               scores
# 0  {'neg': 0.194, 'neu': 0.732, 'pos': 0.073, 'co...
# 1  {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'comp...
# 2  {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'comp...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...

# %%
#Creating Compound column by retrieving compound from dictionary of scores.

covaxin_northeast['compound']=covaxin_northeast['scores'].apply(lambda d:d['compound'])

# %%
#Head of Dataframe after getting Compount Score
covaxin_northeast.head()
# Out:
#      user_location  tweet_created_at  \
# 0  Guwahati, Assam  18-04-2021 05:53
# 1  Guwahati, Assam  18-04-2021 03:17
# 2  Guwahati, India  17-04-2021 18:33
# 3  Guwahati, India  17-04-2021 16:28
# 4  Guwahati, India  17-04-2021 14:27
#
#                                           tweet_text  \
# 0  hello @BharatBiotech @SerumInstIndia please st...
# 1  To increase the supply of #COVID19Vaccine, the...
# 2  @virsanghvi Hypocrite people like you were the...
# 3  @abhijitsarma Hi Dr Abhijit are you administer...
# 4  covid-19 vaccine in assam, covaxin vs covishie...
#
#                                          tweet_clean  \
# 0  hello   please start the production I will pay...
# 1  To increase the supply of  COVID19Vaccine the ...
# 2   Hypocrite people like you were the biggest bo...
# 3   Hi Dr Abhijit are you administering covaxin o...
# 4   covid 19 vaccine in assam covaxin vs covishield
#
#                                               scores  compound
# 0  {'neg': 0.194, 'neu': 0.732, 'pos': 0.073, 'co...   -0.5859
# 1  {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'comp...    0.5267
# 2  {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'comp...    0.6486
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000

# %%
#Creating Sentiments Subdivision Category from the Compound score

covaxin_northeast['sentiment'] = 'Nan'
for i in range(len(covaxin_northeast)):
    # Weak Positive Category
    if(covaxin_northeast['compound'][i] > 0 and covaxin_northeast['compound'][i] < 0.8):
        covaxin_northeast['sentiment'][i] = 'Weak Positive'
    # Strong Positive Category 
    elif(covaxin_northeast['compound'][i]) >= 0.8 and covaxin_northeast['compound'][i] <= 1:
        covaxin_northeast['sentiment'][i] = 'Strong Positive'
    # Weak Negative Category
    elif(covaxin_northeast['compound'][i] < 0 and covaxin_northeast['compound'][i] > -0.8):
        covaxin_northeast['sentiment'][i] = 'Weak Negative'
    # Strong Negative Category
    elif(covaxin_northeast['compound'][i]) <= -0.8 and covaxin_northeast['compound'][i] >= -1:
        covaxin_northeast['sentiment'][i] = 'Strong Negative'
    # Neutral Category
    else:
        covaxin_northeast['sentiment'][i] = 'Neutral'
# Out:
# <ipython-input-208-847c7a01594d>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_northeast['sentiment'][i] = 'Weak Negative'
# <ipython-input-208-847c7a01594d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_northeast['sentiment'][i] = 'Weak Positive'
# <ipython-input-208-847c7a01594d>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_northeast['sentiment'][i] = 'Neutral'
# <ipython-input-208-847c7a01594d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covaxin_northeast['sentiment'][i] = 'Strong Positive'

# %%
#Head of dataframe after 'sentiment' column
covaxin_northeast.head()
# Out:
#      user_location  tweet_created_at  \
# 0  Guwahati, Assam  18-04-2021 05:53
# 1  Guwahati, Assam  18-04-2021 03:17
# 2  Guwahati, India  17-04-2021 18:33
# 3  Guwahati, India  17-04-2021 16:28
# 4  Guwahati, India  17-04-2021 14:27
#
#                                           tweet_text  \
# 0  hello @BharatBiotech @SerumInstIndia please st...
# 1  To increase the supply of #COVID19Vaccine, the...
# 2  @virsanghvi Hypocrite people like you were the...
# 3  @abhijitsarma Hi Dr Abhijit are you administer...
# 4  covid-19 vaccine in assam, covaxin vs covishie...
#
#                                          tweet_clean  \
# 0  hello   please start the production I will pay...
# 1  To increase the supply of  COVID19Vaccine the ...
# 2   Hypocrite people like you were the biggest bo...
# 3   Hi Dr Abhijit are you administering covaxin o...
# 4   covid 19 vaccine in assam covaxin vs covishield
#
#                                               scores  compound      sentiment
# 0  {'neg': 0.194, 'neu': 0.732, 'pos': 0.073, 'co...   -0.5859  Weak Negative
# 1  {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'comp...    0.5267  Weak Positive
# 2  {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'comp...    0.6486  Weak Positive
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        Neutral
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        Neutral

# %%
# Different sentiments category 
covaxin_northeast['sentiment'].value_counts()
# Out:
# Neutral            23
# Weak Positive      18
# Weak Negative       9
# Strong Positive     5
# Name: sentiment, dtype: int64

# %%
# Percentage of Above Different Sentiments Category for Visualisation

for i in range(len(covaxin_northeast['sentiment'].value_counts())):
    percentage = covaxin_northeast['sentiment'].value_counts()[i] / len(covaxin_northeast)
    print(covaxin_northeast['sentiment'].value_counts().index[i], round(percentage*100,2),"%", "rounded to",round(percentage*100),"%")
# Out:
# Neutral 41.82 % rounded to 42 %
# Weak Positive 32.73 % rounded to 33 %
# Weak Negative 16.36 % rounded to 16 %
# Strong Positive 9.09 % rounded to 9 %
